# %%
from pathlib import Path

# %%
pth = Path('/nrs/cosem/davis/s3_testing/macrophage.n5/fibsem/')

# %%
# get all files

# %%
files = sorted(pth.rglob('*'), key=lambda v: len(v.parts))

# %%
len(files)
# Out:
# 127929

# %%
from itertools import groupby

# %%
by_depth = {count: list(paths) for count, paths in groupby(files, lambda v: len(v.parts))}

# %%
by_depth.keys()
# Out:
# dict_keys([8, 9, 10, 11])

# %%
by_depth[11]
# Out:
# [PosixPath('/nrs/cosem/davis/s3_testing/macrophage.n5/fibsem/s0/0/0/0'),
#  PosixPath('/nrs/cosem/davis/s3_testing/macrophage.n5/fibsem/s0/0/0/1'),
#  PosixPath('/nrs/cosem/davis/s3_testing/macrophage.n5/fibsem/s0/0/0/10'),
#  PosixPath('/nrs/cosem/davis/s3_testing/macrophage.n5/fibsem/s0/0/0/11'),
#  PosixPath('/nrs/cosem/davis/s3_testing/macrophage.n5/fibsem/s0/0/0/12'),
#  PosixPath('/nrs/cosem/davis/s3_testing/macrophage.n5/fibsem/s0/0/0/13'),
#  PosixPath('/nrs/cosem/davis/s3_testing/macrophage.n5/fibsem/s0/0/0/14'),
#  PosixPath('/nrs/cosem/davis/s3_testing/macrophage.n5/fibsem/s0/0/0/15'),
#  PosixPath('/nrs/cosem/davis/s3_testing/macrophage.n5/fibsem/s0/0/0/16'),
#  PosixPath('/nrs/cosem/davis/s3_testing/macrophage.n5/fibsem/s0/0/0/17'),
#  PosixPath('/nrs/cosem/davis/s3_testing/macrophage.n5/fibsem/s0/0/0/18'),
#  PosixPath('/nrs/cosem/davis/s3_testing/macrophage.n5/fibsem/s0/0/0/19'),
#  PosixPath('/nrs/cosem/davis/s3_testing/macrophage.n5/fibsem/s0/0/0/2'),
# ...
